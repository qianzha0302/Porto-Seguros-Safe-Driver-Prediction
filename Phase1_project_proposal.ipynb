# %% [markdown]
# # Risk Control Project Features & Plan
#
# > The goal of data science is not to execute instead, to learn, and develop new business capabilities. Data Science is only useful when the data are used to answer the questions.

# %% [markdown]
# ### 10 Applications of data science to reduce risk

# %% [markdown]
# 10 applications of DATA Science to reduce risk and quick processing in various domains is as below:
# 1. Fraud and Risk Detection
# 2. Healthcare
# 3. Internet Search
# 4. Targeted Advertising
# 5. Road Travel
# 6. Government
# 7. Website Recommendations
# 8. Advanced Image Recognition
# 9. Speech Recognition
# 10. Gaming
#
# "What we are currently doing belongs to the first type, which is risk identification.
#
# The data handled in risk control projects is generally imbalanced. When the number of samples from different categories in a dataset for a classification task differs significantly, we usually refer to this dataset as "class-imbalanced."
#
# This happens to be suitable for risk control, as the probability of risks occurring is extremely low. Taking this project as an example, the occurrence of claims by drivers is a very small minority, with the majority of people not filing claims.
#
# As a result, there is a significant disparity in the quantity of positive and negative samples, making it very challenging for the classifier to distinguish the minority class. This will also be a major challenge in this project!"

# %% [markdown]
# ### Outcome Scoring Metric
#
# **Scoring Metric**。
#
#
# >Submissions are evaluated using the Normalized Gini Coefficient.
#
# >During scoring, observations are sorted from the largest to the smallest predictions. Predictions are only used for ordering observations; therefore, the relative magnitude of the predictions are not used during scoring. The scoring algorithm then compares the cumulative proportion of positive class observations to a theoretical uniform proportion.
#
# >The Gini Coefficient ranges from approximately 0 for random guessing, to approximately 0.5 for a perfect score. The theoretical maximum for the discrete calculation is (1 - frac_pos) / 2.
#
# >The Normalized Gini Coefficient adjusts the score by the theoretical maximum so that the maximum score is 1.
#
# >The code to calculate Normalized Gini Coefficient in a number of different languages can be found in this forum thread.

# %%
# TODO: info() Check feature names, non-empty values, and variable types
import pandas as pd
import numpy as np
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595212 entries, 0 to 595211
# Columns: 59 entries, id to ps_calc_20_bin
# dtypes: float64(10), int64(49)
# memory usage: 267.9 MB

# %%
test.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892816 entries, 0 to 892815
# Columns: 58 entries, id to ps_calc_20_bin
# dtypes: float64(10), int64(48)
# memory usage: 395.1 MB

# %%
# TODO: head() first ten rows
train.head(10)
# Out:
#    id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 0   7       0          2              2          5              1
# 1   9       0          1              1          7              0
# 2  13       0          5              4          9              1
# 3  16       0          0              1          2              0
# 4  17       0          0              2          0              1
# 5  19       0          5              1          4              0
# 6  20       0          2              1          3              1
# 7  22       0          5              1          4              0
# 8  26       0          5              1          3              1
# 9  28       1          1              1          2              0
#
#    ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ...  \
# 0              0              0              1              0  ...
# 1              0              0              0              1  ...
# ...

# %%
test.head(10)
# Out:
#    id  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  ps_ind_05_cat  \
# 0   0          0              1          8              1              0
# 1   1          4              2          5              1              0
# 2   2          5              1          3              0              0
# 3   3          0              1          6              0              0
# 4   4          5              1          7              0              0
# 5   5          0              1          6              0              0
# 6   6          0              1          3              0              0
# 7   8          0              1          0              0              0
# 8  10          0              1          7              0              0
# 9  11          1              1          6              0              0
#
#    ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ps_ind_09_bin  ...  \
# 0              0              1              0              0  ...
# ...

# %%
# TODO: tail() last 7 rows
train.tail(7)
# Out:
#              id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 595205  1488009       0          0              3          6              1
# 595206  1488011       0          0              1          2              0
# 595207  1488013       0          3              1         10              0
# 595208  1488016       0          5              1          3              0
# 595209  1488017       0          1              1         10              0
# 595210  1488021       0          5              2          3              1
# 595211  1488027       0          0              1          8              0
#
#         ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ...  \
# 595205              0              0              1              0  ...
# 595206              0              0              0              0  ...
# 595207              0              0              0              0  ...
# ...

# %%
test.tail(7)
# Out:
#              id  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 892809  1488019          2              1          7              0
# 892810  1488020          0              1          6              0
# 892811  1488022          0              1          6              0
# 892812  1488023          5              3          5              1
# 892813  1488024          0              1          5              0
# 892814  1488025          6              1          5              1
# 892815  1488026          7              1          4              1
#
#         ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  \
# 892809              0              0              0              0
# 892810              0              0              0              0
# 892811              0              0              1              0
# 892812              0              0              0              1
# 892813              0              1              0              0
# ...

# %% [markdown]
# **write a function named "check_data" that takes a DataFrame as input and returns a new DataFrame that meets the following conditions：**
#
#
# 1. The new DataFrame has a total of 10 rows.The number of columns in the new DataFrame is the same as the number of columns in the input DataFrame.
# 2. The first 5 rows of the new DataFrame are the same as the first 5 rows of the input DataFrame.
# 3. The last 5 rows of the new DataFrame are the same as the last 5 rows of the input DataFrame.

# %%
def check_data(df):
    return pd.concat([df.head(),df.tail()])

# check
check_data(df = train)
# Out:
#              id  target  ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  \
# 0             7       0          2              2          5              1
# 1             9       0          1              1          7              0
# 2            13       0          5              4          9              1
# 3            16       0          0              1          2              0
# 4            17       0          0              2          0              1
# 595207  1488013       0          3              1         10              0
# 595208  1488016       0          5              1          3              0
# 595209  1488017       0          1              1         10              0
# 595210  1488021       0          5              2          3              1
# 595211  1488027       0          0              1          8              0
#
#         ps_ind_05_cat  ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ...  \
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=185fc705-b61f-4bb6-be30-c3c88dd0b19b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
